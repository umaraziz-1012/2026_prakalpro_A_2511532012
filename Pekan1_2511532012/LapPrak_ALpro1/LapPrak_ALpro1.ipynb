# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“PENGENALAN PHYTON”**
#
# **Disusun Oleh :**
#
# **Umar Abdul Aziz**
#
# **2511532012**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero
#
# **
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum perkenalan Python yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan mengenal Phyton
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep print() pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Phyton merupakan bahasa pemograman yang banyak di gunakan karena memiliki sintak yang sederhana dan mudah di pahami, salah satu konsep dasar dalam pyhton adalah pemograman fungsi print(), dimana fungsi ini digunakan untuk menampilkan teks, angka maupun hasil di layar, oleh karena itu praktikum ini megenalkan fungsi print() sebagaii salah satu perintah dasar.
#
# ## 1.2 Tujuan
# 1. Memahami cara menjalankan python
# 2. Memahami cara menjalankan fungsi print()
# 3. Memahami cara menampilkan teks dan informasi sederhana
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat menggunakan fungsi print() untuk menampilkan output program.
# 2. Mahasiswa memiliki dasar untuk mempelajari konsep pemrograman Python yang lebih  lanjut.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Pythom.
#
# Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python dapat digunakan untuk berbagai kebutuhan pemrograman dan cocok digunakan untuk mempelajari konsep dasar pemrograman.
#
# 2. Fungsi Print().
#
# ini merupakan fungsi bawaan python yang di gunakan untuk menampilkan informasi atau hasil program contoh sintaknya yaitu : print("Hello World")

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Program1.py"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
#Program pertama
"""
Komentar 
dua baris
atau lebih
"""
print("Hello world")
print()
print("program ini menghasilkan")
print("empat baris output")
print("/\\/\\\\///\\\\\\")
print("program ini " + "dibuat oleh a\n" + "nama dan nim")
# Out:
# Hello world
#
# program ini menghasilkan
# empat baris output
# /\/\\///\\\
# program ini dibuat oleh a
# nama dan nim

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama kode ini berfungsi untuk menampilkan komentar, dimana saat di jalankan tidak akan menghasilkan output
# 2. Bagian kedua berfungsi untuk menghasilkan output saat di jalankan

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas1_2511532012"

# %%
nama_2012 = "Aziz"
tanggal_lahir_2012 = "10-12-2006"
tempat_lahir_2012 = "Bukittinggi"

print("perkenalkan nama saya adalah",nama_2012)
print("tanggal lahir saya adalah",tanggal_lahir_2012)
print("tempat lahir saya adalah",tempat_lahir_2012)
# Out:
# perkenalkan nama saya adalah Aziz
# tanggal lahir saya adalah 10-12-2006
# tempat lahir saya adalah Bukittinggi

# %% [markdown]
# **Penjelasan :** Kode program ini adalah kode program print sederhana dimana saya menyimpan data ke tiap variable dan setelah di simpan. nantiknya saya menggunaka fungsi print() untuk menampilkannya

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa sintak print()
#
# Dalam konteks pemrograman python adalah dasar dari segalanya, karena dengan sintak ini pemograman dapat mengeluarkan outputnya

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] W3Schools, "Python Output," W3Schools, 2026. [Online]. Tersedia: https://www.w3schools.com/python/python_output.asp [Diakses 5 September 2026].
